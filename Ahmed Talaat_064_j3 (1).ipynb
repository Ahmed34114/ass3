# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Name:Ahmed Talaat Mersal

# %% [markdown]
# ## junior:j3

# %% [markdown]
# ### Task 1: Develop a plan for a simple developed program that meets specific tasks.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1- Project Name: (convert from csv to JSON)

# %% [markdown]
# 2- Project Description:(This project used to convert from json format to csv format)

# %% [markdown]
# 3-Project Timeline, Milestones:(design for gui 1 week
# Implementation code 1 week
#  total time: 2 weeks)

# %% [markdown]
# 4-Project Flowchart or Pseudo Code.

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# 5-Programming Language Used: python

# %% [markdown]
# 6-Input Format and Layout:
# {
#   "name": ["Ahmed"],
#   "age": [15],
#   "city": ["Assiut"]
# }

# %% [markdown]
# 7-Output Format and Layout:named     age    city
#                             ahmed     15     assuiotu

# %% [markdown]
# 8-One Test Scenario with Input and Expected Output.{
#     "named": ["ahmed"],
#     "age": [15],
#     "city": ["assiut"]
#
#     }

# %% [markdown]
# 272_PGN

# %% [markdown]
# ### Task 2: Write code for the prepared design.

# %% [markdown]
# #### part 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
file = pd.read_json(r"C:\Users\EVO TECH\Desktop\New folder\New Text Document (2).json")
file.to_csv(r"C:\Users\EVO TECH\Desktop\New folder\New Text Document (2).csv")
#Import pands
#opin file json
#opin fie csv

# %% [markdown]
# ### Task 3: Ensure the use of source control, such as GIT.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Creates a storage cloud for the project (Repository).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Copies the project from the cloud (Clone).

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 3. Adds two text files to the repository.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 4. Documents the modification in the project (commit).

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 5. Modifies one of the text files.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 6. Documents the modification in the project (commit).

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 7. Pulls other updates from the cloud (pull).

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 8. Publishes the documented changes to the cloud (push).

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
